# %% [markdown]
# # Required library

# %%
import pandapower as pp
import pandas as pd
# Install pandapower in a new environment by pip install pandapower==2.13.1

# %% [markdown]
# # Load network

# %%
# a = pd.read_pickle('C:/Users/bjorn/OneDrive/Documents/TU Delft/BEP/Forecasting/ScPaper/bap/aggregated_grid_2018_with_generators_loads_costs_controllers.p')
# a

# %%
net = pp.from_pickle('C:/Users/bjorn/OneDrive/Documents/TU Delft/BEP/TUD Library/bap/aggregated_grid_2018_with_generators_loads_costs_controllers.p')
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (45 element)
#    - load (132 element)
#    - sgen (43 element)
#    - gen (69 element)
#    - ext_grid (10 element)
#    - line (92 element)
#    - trafo (3 element)
#    - pwl_cost (10 element)
#    - poly_cost (108 element)
#    - controller (173 element)
#    - bus_geodata (45 element)

# %%
net.bus
# Out:
#        name  vn_kv type                                       zone  \
# 0    EEM220  220.0    b                      Station Eemshaven 220
# 1    ENS220  220.0    b                            Station Ens 220
# 2    HSW220  220.0    b                      Station Hessenweg 220
# 3    LSM220  220.0    b                      Station Louwsmeer 220
# 4    MEE220  220.0    b                         Station Meeden 220
# 5    OHK220  220.0    b                      Station Oudehaske 220
# 6    RBB220  220.0    b                    Station Robbenplaat 220
# 7    VVL220  220.0    b                   Station Vierverlaten 220
# 8    WEW220  220.0    b                        Station Weiwerd 220
# 9    ZYV220  220.0    b                      Station Zeyerveen 220
# 10   BKK380  380.0    b             Station Breukelen Kortrijk 380
# 11   BSL380  380.0    b                       Station Borssele 380
# 12   BVW380  380.0    b                      Station Beverwijk 380
# ...

# %%
net.res_gen #before running
# Out:
# Empty DataFrame
# Columns: [p_mw, q_mvar, va_degree, vm_pu]
# Index: []

# %%
net.res_gen #after running
# Out:
#       p_mw     q_mvar  va_degree  vm_pu
# 0    125.0 -28.746864   0.023228    1.0
# 1    125.0 -28.746864   0.023228    1.0
# 2      7.0 -15.188644   7.075942    1.0
# 3     38.0 -12.059701   6.707297    1.0
# 4    485.0 -29.617331   5.453460    1.0
# 5     48.0 -18.156854   7.425136    1.0
# 6    455.0 -29.617331   5.453460    1.0
# 7    844.0 -28.746864   0.023228    1.0
# 8     72.0 -27.645506   9.801581    1.0
# 9     72.0 -27.645506   9.801581    1.0
# 10   131.0  24.208598   4.048170    1.0
# 11   359.0  24.208598   4.048170    1.0
# 12   359.0  24.208598   4.048170    1.0
# 13   361.0  24.208598   4.048170    1.0
# 14   359.0 -50.888584   0.029281    1.0
# 15   360.0 -50.888584   0.029281    1.0
# 16   426.0 -70.386763   8.520497    1.0
# 17   415.0 -70.386763   8.520497    1.0
# 18    83.0  31.196488   3.572025    1.0
# 19   112.0  66.472085   2.382366    1.0
# 20    24.0  -1.697267   3.874788    1.0
# 21    24.0  -1.697267   3.874788    1.0
# ...

# %%
net.gen
# Out:
#                                      name  bus    p_mw  vm_pu  sn_mva  \
# 0                   Pergen Power Station    28   125.0    1.0     NaN
# 1                   Pergen Power Station    28   125.0    1.0     NaN
# 2                              Amylum Gas   29     7.0    1.0     NaN
# 3                               Corus CHP   12    38.0    1.0     NaN
# 4                   Kerncentrale Borssele   11   485.0    1.0     NaN
# 5         Attero Waste Incineration Plant    9    48.0    1.0     NaN
# 6                          ELSTA centrale   11   455.0    1.0     NaN
# 7                                EnecoGen   28   844.0    1.0     NaN
# 8                         Centrale Bergum    3    72.0    1.0     NaN
# 9                         Centrale Bergum    3    72.0    1.0     NaN
# 10                           Eemscentrale    6   131.0    1.0     NaN
# 11                           Eemscentrale    6   359.0    1.0     NaN
# ...

# %%
from pandapower.timeseries.output_writer import OutputWriter

ow = OutputWriter(net, output_path="C:/Users/bjorn/OneDrive/Documents/TU Delft/BEP/TUD Library/bap/Results", output_file_type=".xlsx") # create an OutputWriter
ow.log_variable('res_bus', 'vm_pu') # add logging for bus voltage magnitudes
ow.log_variable('res_line', 'loading_percent') # add logging for line loadings in percent
ow.log_variable('res_gen', 'p_mw')
ow.log_variable('res_sgen', 'p_mw')
ow.log_variable('res_load', 'p_mw')

# %%
n_ts = 8760 # number of hours in one year
ts = range(0, n_ts)
pp.timeseries.run_timeseries(net, continue_on_divergence=True)
# Out:
# No time steps to calculate are specified. I'll check the datasource of the first controller for avaiable time steps
# c:\Users\bjorn\miniconda3\lib\site-packages\pandapower\timeseries\output_writer.py:177: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'range(0, 8760)' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   self.output["Parameters"].loc[:, "time_step"] = self.time_steps
# c:\Users\bjorn\miniconda3\lib\site-packages\pandapower\control\run_control.py:50: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   level = controller.level.fillna(0).apply(asarray).values
# ...
# 100%|██████████| 8760/8760 [05:16<00:00, 27.69it/s]

# %%
net.load
# Out:
#                                     name  bus        p_mw  q_mvar  \
# 0                             Amsterdam1   29   97.263685     0.0
# 1                             Amsterdam2   15   97.263685     0.0
# 2                             Rotterdam1   24   70.061476     0.0
# 3                             Rotterdam2   33   70.061476     0.0
# 4                               Den Haag   33  113.638151     0.0
# 5                                Utrecht   10   82.847403     0.0
# 6               Aggregated Households NH   29  368.011856     0.0
# 7               Aggregated Households ZH   32  487.453119     0.0
# 8               Aggregated Households ZL   11   73.783328     0.0
# 9               Aggregated Households FL   25   81.364744     0.0
# 10              Aggregated Households GL   17  425.134952     0.0
# 11              Aggregated Households GR    6  123.010480     0.0
# 12              Aggregated Households FR    3  118.413130     0.0
# ...

# %% [markdown]
# ## Getting TimeSeries load data

# %%
net.controller
# Out:
#                                       object  in_service  order level  \
# 0                   ConstControl [load.p_mw]        True   -1.0    -1
# 1                   ConstControl [load.p_mw]        True   -1.0    -1
# 2                   ConstControl [load.p_mw]        True   -1.0    -1
# 3                   ConstControl [load.p_mw]        True   -1.0    -1
# 4                   ConstControl [load.p_mw]        True   -1.0    -1
# 5                   ConstControl [load.p_mw]        True   -1.0    -1
# 6                   ConstControl [load.p_mw]        True   -1.0    -1
# 7                   ConstControl [load.p_mw]        True   -1.0    -1
# 8                   ConstControl [load.p_mw]        True   -1.0    -1
# 9                   ConstControl [load.p_mw]        True   -1.0    -1
# 10                  ConstControl [load.p_mw]        True   -1.0    -1
# 11                  ConstControl [load.p_mw]        True   -1.0    -1
# ...

# %%
net.sgen #Renewable energy
# Out:
#                               name  bus     p_mw  q_mvar  sn_mva  scaling  \
# 0                  Windpark Gemini   21  600.000     0.0     NaN      1.0
# 1           Windpark Luchterduinen   13  129.000     0.0     NaN      1.0
# 2          Windpark Prinses Amalia   12  120.000     0.0     NaN      1.0
# 3            Windpark NoordzeeWind   12  108.000     0.0     NaN      1.0
# 4          Windpark Prinses Alexia   15  122.000     0.0     NaN      1.0
# 5              Windpark Westereems    6  171.000     0.0     NaN      1.0
# 6   Windpark Noordoostpolder Water    5  144.000     0.0     NaN      1.0
# 7    Windpark Noordoostpolder Land    5  285.000     0.0     NaN      1.0
# 8                 Windpark Krammer   28  102.000     0.0     NaN      1.0
# 9           Windpark Kreekraksluis   30   82.500     0.0     NaN      1.0
# 10         Windpark Delfzijl Noord    8   62.700     0.0     NaN      1.0
# 11             Windpark Slufterdam   28   50.400     0.0     NaN      1.0
# ...

# %%
gens_0  = net.controller.object[132].data_source.to_dict()['df']
gens_0
# Out:
#             p_mw
# 0     564.805929
# 1     587.079077
# 2     594.880740
# 3     594.617733
# 4     595.436474
# 5     595.809102
# 6     595.485034
# 7     595.843939
# 8     595.483670
# 9     594.432982
# 10    594.368857
# 11    591.929820
# 12    584.288166
# 13    571.392179
# 14    551.170155
# 15    520.770000
# 16    485.074302
# 17    449.572682
# 18    407.007507
# 19    369.570228
# 20    336.359694
# 21    317.866938
# 22    311.735473
# 23    309.302448
# 24    303.828403
# 25    291.464840
# 26    297.649606
# 27    343.311845
# 28    417.025238
# 29    467.221007
# 30    467.829723
# 31    434.303973
# 32    427.109959
# 33    471.977142
# 34    492.236569
# 35    410.006403
# 36    454.449747
# 37    495.365856
# 38    526.258736
# 39    535.534386
# 40    555.066276
# 41    567.076895
# 42    580.347215
# 43    592.592478
# 44    595.910924
# 45    595.555815
# 46    589.620722
# 47    584.446513
# 48    583.722542
# 49    592.685920
# 50    595.846304
# ...

# %%
pp.runpp(net)

# %%
pp.timeseries.run_time_series.run_timeseries(net, time_steps=(0,95))

# %%
net.line

# %%
net.load.groupby('bus').count
# Out:
# <bound method GroupBy.count of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000206B671CFD0>>

# %%
net.ext_grid #slack busses?

# %%
load_0  = net.controller.object[0].data_source.to_dict()['df']
load_0
# Out:
#              E1A
# 0      90.359716
# 1      73.058060
# 2      55.899492
# 3      42.020010
# 4      37.482946
# 5      36.248817
# 6      39.450399
# 7      43.236254
# 8      53.353728
# 9      62.421894
# 10     80.307823
# 11     93.281084
# 12     94.038255
# 13     95.105449
# 14     92.661039
# 15     91.295746
# 16     96.476704
# 17    127.687651
# 18    133.768867
# 19    131.282723
# 20    129.500092
# 21    109.759987
# 22     98.402422
# 23     81.100766
# 24     50.998747
# 25     39.170186
# 26     35.414140
# 27     34.162125
# 28     34.460224
# 29     37.858551
# 30     48.965713
# 31     66.499886
# 32     77.171824
# 33     84.087717
# 34     83.968477
# 35     82.537603
# 36     82.597222
# 37     81.285588
# 38     79.198896
# 39     81.583686
# 40     95.415472
# 41    124.217780
# 42    136.320593
# 43    138.699421
# 44    130.597095
# 45    117.295926
# 46     97.979122
# 47     73.177300
# 48     51.952663
# 49     39.378855
# 50     35.831479
# ...
